# %% [markdown]
# ### Notebooks are great for doing manual tests. :)

# %%
from django_for_jupyter import init_django
init_django('dividends_project')

# %%
import requests
import yfinance as yf

from dividends_info.models import StockInfo
import datetime
import hashlib
from django.core.cache import cache
from decouple import config
import json
import re

#Used:
# yahoo_obj.dividends,

# %%
print(YahooStock('MSFT', years=3))
# Out:
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# name 're' is not defined
# Unknown error parsing earnings history dataframe
# []
# ({'dividend_change_1_year': 10.7, 'dividend_change_3_year': 11.6, 'dividend_change_5_year': 11.8, 'dividend_change_10_year': 21.0, 'current_yield': 0.87, 'recent_dividend_rate': 2.48, 'all_dividends': [{'date': '08/17/2022', 'amount': 0.62}, {'date': '05/18/2022', 'amount': 0.62}, {'date': '02/16/2022', 'amount': 0.62}, {'date': '11/17/2021', 'amount': 0.62}, {'date': '08/18/2021', 'amount': 0.56}, {'date': '05/19/2021', 'amount': 0.56}, {'date': '02/17/2021', 'amount': 0.56}, {'date': '11/18/2020', 'amount': 0.56}, {'date': '08/19/2020', 'amount': 0.51}, {'date': '05/20/2020', 'amount': 0.51}, {'date': '02/19/2020', 'amount': 0.51}, {'date': '11/20/2019', 'amount': 0.51}], 'name': 'Microsoft Corporation', 'summary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.', 'sector': 'Technology', 'current_price': 286.15, 'earnings': []}, [{'date': datetime.date(2003, 2, 19), 'amount': 0.08}, {'date': datetime.date(2003, 10, 15), 'amount': 0.16}, {'date': datetime.date(2004, 8, 23), 'amount': 0.08}, {'date': datetime.date(2004, 11, 15), 'amount': 3.08}, {'date': datetime.date(2005, 2, 15), 'amount': 0.08}, {'date': datetime.date(2005, 5, 16), 'amount': 0.08}, {'date': datetime.date(2005, 8, 15), 'amount': 0.08}, {'date': datetime.date(2005, 11, 15), 'amount': 0.08}, {'date': datetime.date(2006, 2, 15), 'amount': 0.09}, {'date': datetime.date(2006, 5, 15), 'amount': 0.09}, {'date': datetime.date(2006, 8, 15), 'amount': 0.09}, {'date': datetime.date(2006, 11, 14), 'amount': 0.1}, {'date': datetime.date(2007, 2, 13), 'amount': 0.1}, {'date': datetime.date(2007, 5, 15), 'amount': 0.1}, {'date': datetime.date(2007, 8, 14), 'amount': 0.1}, {'date': datetime.date(2007, 11, 13), 'amount': 0.11}, {'date': datetime.date(2008, 2, 19), 'amount': 0.11}, {'date': datetime.date(2008, 5, 13), 'amount': 0.11}, {'date': datetime.date(2008, 8, 19), 'amount': 0.11}, {'date': datetime.date(2008, 11, 18), 'amount': 0.13}, {'date': datetime.date(2009, 2, 17), 'amount': 0.13}, {'date': datetime.date(2009, 5, 19), 'amount': 0.13}, {'date': datetime.date(200 ...
